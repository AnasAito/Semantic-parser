# %% [markdown]
# # Simple Example

# %% [markdown]
# ## Utils

# %%
from bs4 import BeautifulSoup
import requests 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
## utils 

def get_shemantic_paper_html(where):
    '''
    get page html using filters on citation list
    
    arguments : paper href 
    output : paper html 
    
    
    '''
    
    base_url = 'https://www.semanticscholar.org'
    filter_ = '?citationRankingModelVersion=v0.2.0-0.01&citedPapersSort=relevance&citedPapersLimit=10&citedPapersOffset=0&sort=is-influential'
    URL = base_url+where+filter_
    
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    return soup 
def extract_data(soup):
    ## init 
    data = {}
    cits_list=[]
    refs_list = []
    ## genral info 
    data["title"] = soup.find('h1' , {'data-selenium-selector':'paper-detail-title'}).text
    data['corpus_id'] = soup.find('span' , {'data-selenium-selector':'corpus-id'}).text
    data["additional_data"] = soup.find('span' , {'data-selenium-selector':'year-and-venue'}).text
    ## citations
    score_card = soup.find('span' , {'class':'scorecard-stat__headline'})
    if score_card : 
        
        data["citation_count"] = score_card.text.split(" ")[0]
        
        ## citations type
        citations_count = [div.text for div in  soup.find_all('div' , {'class':'scorecard-citation__metadata-item'})]
        citations_title = [div.text for div in soup.find_all('div' , {'class':'scorecard-citation__title'})]
        if len(citations_title)< len(citations_count) :
            citations_title.insert(0,'Highly Influencial Citations')
            
        data['citations_overview'] = {"cit_titles":citations_title , "cit_count" : citations_count }
        
    else : 
        data["citation_count"] = ''
        data['citations_overview'] ={}
     
    ## paper topics 
    is_topics = soup.find_all('h4',{'class':'card-sidebar__title'})
    if is_topics : 
        data['topics'] = [span.text for span in soup.find_all('span',{'class' :'preview-box__target' })]
    else : data['topics'] = []
    
    ## main citations , refs 
    cards = soup.find_all('div', class_='cl-paper-row citation-list__paper-row')
    citations_cards = cards[:10]
    refs_cards = cards [10:]

    for cit in citations_cards : 
        entry = {}
        entry['title'] = cit.find('div' , class_='cl-paper-title').text
        entry['link'] = cit.find('a')['href']
        
        stats_raw = cit.find('div',class_='cl-paper-controls__stats')#.find_all('div',class_='cl-paper-stat') 
        if stats_raw :
            stats = [div.text for div in stats_raw.find_all('div',class_='cl-paper-stat') ]
            #print(stats)
            entry['stats']=stats
        else : 
            entry['stats']=[]


        cits_list.append(entry)
    for ref in refs_cards : 
        entry = {}
        entry['title'] = ref.find('div' , class_='cl-paper-title').text
        entry['link'] = ref.find('a')['href']
        
        stats_raw = ref.find('div',class_='cl-paper-controls__stats')#.find_all('div',class_='cl-paper-stat') 
        if stats_raw :
            stats = [div.text for div in stats_raw.find_all('div',class_='cl-paper-stat') ]
            #print(stats)
            entry['stats']=stats
        else : 
            entry['stats']=[]


        refs_list.append(entry)
        
            

    data['citations'] = cits_list
    data['references'] = refs_list
    
    ## return data dict 
    return data 

def ravel(list_):return [j for sub in list_ for j in sub]
 
def generate_wcloud(topics_list,max_words=100,stopwords_list =['learning','neural' , 'computer','algorithm','network','Artificial','model']):
    '''
    args : 1d topics list (1 x n)
    output : word cloud image 
    '''
    text = ' '.join(topics_list)
    
    # lower max_font_size, change the maximum number of word and lighten the background:
    stopwords = set(stopwords_list)
    wordcloud = WordCloud(max_font_size=100,stopwords=stopwords, max_words=max_words, background_color="white" ).generate(text)
    print(wordcloud)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Example

# %%
paper_where = '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214'
soup = get_shemantic_paper_html(paper_where)
data = extract_data(soup)
data
# Out:
# {'title': 'Generative Adversarial Nets',
#  'corpus_id': 'Corpus ID: 1033682',
#  'additional_data': 'Published in NIPS 2014',
#  'citation_count': '19,632',
#  'citations_overview': {'cit_titles': ['Highly Influencial Citations',
#    'Background Citations',
#    ' Methods Citations',
#    ' Results Citations'],
#   'cit_count': ['3,770', '11,305', '6,531', '176']},
#  'topics': ['Generative model',
#   'Discriminative model',
#   'Backpropagation',
#   'Minimax',
#   'Markov chain',
#   'Multilayer perceptron',
#   'Assignment (computer science)',
#   'Approximation algorithm',
#   'Experiment'],
#  'citations': [{'title': 'Generative Adversarial Learning Towards Fast Weakly Supervised Detection',
#    'link': '/paper/Generative-Adversarial-Learning-Towards-Fast-Weakly-Shen-Ji/862b9feff7c5f40736d83bbf10abe32c2702c490',
#    'stats': ['40', 'Highly Influenced', 'PDF']},
#   {'title': 'Unsupervised Representation Learning with Prior-Free and Adversarial Mechanism Embedded Autoencoders',
#    'link': '/paper/Unsupervised-Representation-Learning-with-and-Gao-Xiong/8ce39d0c196c422a009e04bdd06951207ce8f465',
#    'stats': []},
#   {'title': 'Computer Vision – ECCV 2020: 16th European Conference, Glasgow, UK, August 23–28, 2020, Proceedings, Part XXVIII',
#    'link': '/paper/Computer-Vision-%E2%80%93-ECCV-2020%3A-16th-European-Glasgow%2C-Vedaldi-Bischof/0cd444d79c4b00cf824a8f2dbb16467727c729d9',
#    'stats': []},
#   {'title': 'GAN and VAE from an Optimal Transport Point of View',
#    'link': '/paper/GAN-and-VAE-from-an-Optimal-Transport-Point-of-View-Genevay-Peyr%C3%A9/fdd72abcfab06548e862ec45015427dbcf78e3ae',
#    'stats': ['29', 'Highly Influenced', 'PDF']},
#   {'title': 'Adversarial Dual Network Learning With Randomized Image Transform for Restoring Attacked Images',
#    'link': '/paper/Adversarial-Dual-Network-Learning-With-Randomized-Yuan-He/7c77316722435a87f8f7fffe181df7249a062491',
#    'stats': ['2', 'Highly Influenced']},
#   {'title': 'Progressive Reconstruction of Visual Structure for Image Inpainting',
#    'link': '/paper/Progressive-Reconstruction-of-Visual-Structure-for-Li-He/16cb1f83d0c68db6e32a4009804f6b346287f188',
#    'stats': ['10', 'Highly Influenced', 'PDF']},
#   {'title': 'Improving k-Means Clustering Performance with Disentangled Internal Representations',
#    'link': '/paper/Improving-k-Means-Clustering-Performance-with-Agarap-Azcarraga/856afe8f057c495e8837689273ac4d00eded6379',
#    'stats': []},
#   {'title': 'Distributionally Robust Games: Wasserstein Metric',
#    'link': '/paper/Distributionally-Robust-Games%3A-Wasserstein-Metric-Gao-Tembine/1667b7c68e733f95f81c12e6cac73e5f659abca1',
#    'stats': ['2', 'Highly Influenced']},
#   {'title': 'GenEval: A Benchmark Suite for Evaluating Generative Models',
#    'link': '/paper/GenEval%3A-A-Benchmark-Suite-for-Evaluating-Models-Bakhtin-Szlam/35d0a1012519f71af2203b67bf93caabd7fdc4bb',
#    'stats': []},
#   {'title': 'Towards Structured Prediction in Bioinformatics with Deep Learning',
#    'link': '/paper/Towards-Structured-Prediction-in-Bioinformatics-Li/4f53d0fb9528f2fd6d4ac6515b23f5f2ad66fc63',
#    'stats': []}],
#  'references': [{'title': 'Deep Generative Stochastic Networks Trainable by Backprop',
#    'link': '/paper/Deep-Generative-Stochastic-Networks-Trainable-by-Bengio-Thibodeau-Laufer/5ffa8bf1bf3e39227be28de4ff6915d3b21eb52d',
#    'stats': ['313', 'PDF']},
#   {'title': 'A Generative Process for sampling Contractive Auto-Encoders',
#    'link': '/paper/A-Generative-Process-for-sampling-Contractive-Rifai-Bengio/aaaea06da21f22221d5fbfd61bb3a02439f0fe02',
#    'stats': ['66']},
#   {'title': 'Learning Generative Models via Discriminative Approaches',
#    'link': '/paper/Learning-Generative-Models-via-Discriminative-Tu/23b80dc704e25cf52b5a14935002fc083ce9c317',
#    'stats': ['99', 'PDF']},
#   {'title': 'Generalized Denoising Auto-Encoders as Generative Models',
#    'link': '/paper/Generalized-Denoising-Auto-Encoders-as-Generative-Bengio-Yao/d9704f8119d6ba748230b4f2ad59f0e8c64fdfb0',
#    'stats': ['362', 'PDF']},
#   {'title': 'Deep AutoRegressive Networks',
#    'link': '/paper/Deep-AutoRegressive-Networks-Gregor-Danihelka/695a2c95eacdbccb7a73d2f1e90e7b35b4b3d864',
#    'stats': ['187', 'PDF']},
#   {'title': 'Learning Multiple Layers of Features from Tiny Images',
#    'link': '/paper/Learning-Multiple-Layers-of-Features-from-Tiny-Krizhevsky/5d90f06bb70a0a3dced62413346235c02b1aa086',
#    'stats': ['9,740', 'PDF']},
#   {'title': 'A Fast Learning Algorithm for Deep Belief Nets',
#    'link': '/paper/A-Fast-Learning-Algorithm-for-Deep-Belief-Nets-Hinton-Osindero/8978cf7574ceb35f4c3096be768c7547b28a35d0',
#    'stats': ['11,383', 'PDF']},
#   {'title': 'Neural Variational Inference and Learning in Belief Networks',
#    'link': '/paper/Neural-Variational-Inference-and-Learning-in-Belief-Mnih-Gregor/018300f5f0e679cee5241d9c69c8d88e00e8bf31',
#    'stats': ['535', 'PDF']},
#   {'title': 'Auto-Encoding Variational Bayes',
#    'link': '/paper/Auto-Encoding-Variational-Bayes-Kingma-Welling/5f5dc5b9a2ba710937e2c413b37b053cd673df02',
#    'stats': ['10,212', 'Highly Influential', 'PDF']},
#   {'title': 'Stochastic Backpropagation and Approximate Inference in Deep Generative Models',
#    'link': '/paper/Stochastic-Backpropagation-and-Approximate-in-Deep-Rezende-Mohamed/484ad17c926292fbe0d5211540832a8c8a8e958b',
#    'stats': ['2,893', 'PDF']}]}

# %% [markdown]
# ## Hard test on scrap function
# - scrap root paper then scap citations papers and refs

# %%
dta = []
paper_where = '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214'
soup = get_shemantic_paper_html(paper_where)
data = extract_data(soup)
dta.append(data)
for cit in data['citations'] : 

    print(cit['title'])
    soup = get_shemantic_paper_html(cit['link'])
    data = extract_data(soup)
    dta.append(data)
    print(data)
    print('-----------')
# Out:
# Generative Adversarial Learning Towards Fast Weakly Supervised Detection
# {'title': 'Generative Adversarial Learning Towards Fast Weakly Supervised Detection', 'corpus_id': 'Corpus ID: 51996510', 'additional_data': 'Published 2018', 'citation_count': '40', 'citations_overview': {'cit_titles': ['Highly Influencial Citations', 'Background Citations', ' Methods Citations'], 'cit_count': ['2', '14', '21']}, 'topics': ['Supervised learning', 'Sensor', 'Object detection', 'Structural similarity', 'Programming paradigm', 'Ground truth', 'Procedural generation', 'Feedback', 'Experiment', 'Speedup', 'Minimum bounding box', 'Solid-state drive', 'Real-time clock'], 'citations': [{'title': 'C-MIDN: Coupled Multiple Instance Detection Network With Segmentation Guidance for Weakly Supervised Object Detection', 'link': '/paper/C-MIDN%3A-Coupled-Multiple-Instance-Detection-Network-Yan-Liu/78efaed39a08fb61195701eaf054e3e27b22d03b', 'stats': ['11', 'Highly Influenced', 'PDF']}, {'title': 'Cyclic Guidance for Weakly Supervised Joint Detection and Segmentation', 'link': '/paper/Cyclic-Guidance-for-Weakly-Supervised-Joint-and-Shen-Ji/b59cf640d0f43c38b5ad4bce0c1991f1078fcd19', 'stats': ['20', 'PDF']}, {'title': 'Forget and Diversify: Regularized Refinement for Weakly Supervised Object Detection', 'link': '/paper/Forget-and-Diversify%3A-Regularized-Refinement-for-Son-Kim/842079831514095e904ad3543c9b6a3bf407837f', 'stats': ['3', 'Highly Influenced', 'PDF']}, {'title': 'Salient Object Detection Techniques in Computer Vision—A Survey', 'link': '/paper/Salient-Object-Detection-Techniques-in-Computer-Gupta-Seal/c04d9e067cfcb805b20ac514b42085fc81a7bccd', 'stats': []}, {'title': 'Enabling Deep Residual Networks for Weakly Supervised Object Detection', 'link': '/paper/Enabling-Deep-Residual-Networks-for-Weakly-Object-Shen-Ji/9a3414b15ef429c565713d84985cd9a01b2399e3', 'stats': []}, {'title': 'UFO$^2$: A Unified Framework towards Omni-supervised Object Detection', 'link': '/paper/UFO%24%5E2%24%3A-A-Unified-Framework-towards-Object-Ren-Yu/a0f5ba8bb1baedd80b36aca467f40f32df8cceba', 'stats': []}, {'title': 'COUNT-GUIDED WEAKLY SUPERVISED LOCALIZA-', 'link': '/paper/COUNT-GUIDED-WEAKLY-SUPERVISED-LOCALIZA/86c055d6a31d91ffec2d4813f5b34b0d854e3e5e', 'stats': []}, {'title': 'Camouflaged Object Detection', 'link': '/paper/Camouflaged-Object-Detection-Fan-Ji/e5fb1c378086d072104b14f4fb2df9cf1da4b08c', 'stats': ['26', 'PDF']}, {'title': 'Object-Aware Instance Labeling for Weakly Supervised Object Detection', 'link': '/paper/Object-Aware-Instance-Labeling-for-Weakly-Object-Kosugi-Yamasaki/dfa68bc6b86894b7562ff78337b3bf2c0d13a847', 'stats': ['10', 'PDF']}, {'title': 'Weakly Supervised Object Localization using Min-Max Entropy: an Interpretable Framework', 'link': '/paper/Weakly-Supervised-Object-Localization-using-Min-Max-Belharbi-Rony/7c841fb3ba14aade8f33f8a23d4a2646e827be7f', 'stats': ['1', 'PDF']}], 'references': [{'title': 'A-Fast-RCNN: Hard Positive Generation via Adversary for Object Detection', 'link': '/paper/A-Fast-RCNN%3A-Hard-Positive-Generation-via-Adversary-Wang-Shrivastava/bbb6ef63bec6db62e1bdfb5137ba7f7a42a507d4', 'stats': ['288', 'PDF', '']}, {'title': 'Deep Self-Taught Learning for Weakly Supervised Object Localization', 'link': '/paper/Deep-Self-Taught-Learning-for-Weakly-Supervised-Jie-Wei/b7779b0c9399ab0062c4bfa87fa101f0dc4df7a7', 'stats': ['113', 'Highly Influential', 'PDF', '']}, {'title': 'Soft Proposal Networks for Weakly Supervised Object Localization', 'link': '/paper/Soft-Proposal-Networks-for-Weakly-Supervised-Object-Zhu-Zhou/e212e2154628ac913cb95994b25e4f038df75f06', 'stats': ['86', 'PDF', '']}, {'title': 'Weakly Supervised Object Detection via Object-Specific Pixel Gradient', 'link': '/paper/Weakly-Supervised-Object-Detection-via-Pixel-Shen-Ji/1b3166913b72ac6faf6e6dbc5e96a9e53cd577c6', 'stats': ['20', 'PDF', '']}, {'title': 'Self-taught object localization with deep networks', 'link': '/paper/Self-taught-object-localization-with-deep-networks-Bazzani-Bergamo/bd2f443fc18947d2c9ecb81192b3f0a9cd2cf3f1', 'stats': ['109 ...
# -----------
# Unsupervised Representation Learning with Prior-Free and Adversarial Mechanism Embedded Autoencoders
# {'title': 'Unsupervised Representation Learning with Prior-Free and Adversarial Mechanism Embedded Autoencoders', 'corpus_id': 'Corpus ID: 52961948', 'additional_data': 'Published 2018', 'citation_count': '', 'citations_overview': {}, 'topics': ['Supervised learning', 'Feature learning', 'Unsupervised learning', 'Embedded system', 'Artificial neural network', 'Machine learning', 'High- and low-level', 'Pixel', 'Adversary (cryptography)', "Eisenstein's criterion"], 'citations': [{'title': 'Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks', 'link': '/paper/Unsupervised-Representation-Learning-with-Deep-Radford-Metz/8388f1be26329fa45e5807e968a641ce170ea078', 'stats': ['7,067', 'Highly Influential', 'PDF']}, {'title': 'Adversarial Feature Learning', 'link': '/paper/Adversarial-Feature-Learning-Donahue-Kr%C3%A4henb%C3%BChl/1db6e3078597386ac4222ba6c3f4f61b61f53539', 'stats': ['983', 'Highly Influential', 'PDF']}, {'title': 'Stacked Denoising Autoencoders: Learning Useful Representations in a Deep Network with a Local Denoising Criterion', 'link': '/paper/Stacked-Denoising-Autoencoders%3A-Learning-Useful-in-Vincent-Larochelle/e2b7f37cd97a7907b1b8a41138721ed06a0b76cd', 'stats': ['4,601', 'PDF']}, {'title': 'Unsupervised Learning of Visual Structure using Predictive Generative Networks', 'link': '/paper/Unsupervised-Learning-of-Visual-Structure-using-Lotter-Kreiman/b7d5d7e2e0b4af3ff8a7b1f7ee59281eca6e47e6', 'stats': ['91', 'PDF']}, {'title': 'Building high-level features using large scale unsupervised learning', 'link': '/paper/Building-high-level-features-using-large-scale-Le-Ranzato/72e93aa6767ee683de7f001fa72f1314e40a8f35', 'stats': ['1,911', 'PDF']}, {'title': 'Generative Adversarial Nets', 'link': '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214', 'stats': ['19,631', 'Highly Influential', 'PDF']}, {'title': 'Adversarially Learned Inference', 'link': '/paper/Adversarially-Learned-Inference-Dumoulin-Belghazi/fcf43325529c8b1cc26aeb52fd5d7e532abb0a40', 'stats': ['839', 'Highly Influential', 'PDF']}, {'title': 'An Analysis of Single-Layer Networks in Unsupervised Feature Learning', 'link': '/paper/An-Analysis-of-Single-Layer-Networks-in-Feature-Coates-Ng/be9a17321537d9289875fe475b71f4821457b435', 'stats': ['1,990', 'PDF']}, {'title': 'ICA with Reconstruction Cost for Efficient Overcomplete Feature Learning', 'link': '/paper/ICA-with-Reconstruction-Cost-for-Efficient-Feature-Le-Karpenko/51e93552fe55be91a5711ff2aabc04b742503e68', 'stats': ['283', 'PDF']}, {'title': 'Adaptive deconvolutional networks for mid and high level feature learning', 'link': '/paper/Adaptive-deconvolutional-networks-for-mid-and-high-Zeiler-Taylor/d743430cb2329caa5d446c17fc9ec07f5e916ab0', 'stats': ['833', 'Highly Influential', 'PDF']}], 'references': []}
# -----------
# Computer Vision – ECCV 2020: 16th European Conference, Glasgow, UK, August 23–28, 2020, Proceedings, Part XXVIII
# {'title': 'Computer Vision – ECCV 2020: 16th European Conference, Glasgow, UK, August 23–28, 2020, Proceedings, Part XXVIII', 'corpus_id': 'Corpus ID: 226231719', 'additional_data': 'Published 2020', 'citation_count': '', 'citations_overview': {}, 'topics': [], 'citations': [{'title': 'Visual Tracking with Fully Convolutional Networks', 'link': '/paper/Visual-Tracking-with-Fully-Convolutional-Networks-Wang-Ouyang/bf94906f0d7a8ca9da5f6b86e2a476fde1a34dd0', 'stats': ['761', 'PDF']}, {'title': 'A Dual Decomposition Approach to Feature Correspondence', 'link': '/paper/A-Dual-Decomposition-Approach-to-Feature-Torresani-Kolmogorov/977d63d1ad9f03a1e08b900ba76e2f1602f020db', 'stats': ['76', 'Highly Influential']}, {'title': 'Very Deep Convolutional Networks for Large-Scale Image Recognition', 'link': '/paper/Very-Deep-Convolutional-Networks-for-Large-Scale-Simonyan-Zisserman/eb42cf88027de515750f230b23b1a057dc782108', 'stats': ['42,589', 'Highly Influential', 'PDF']}, {'title': 'Context Encoding for Semantic Segmentation', 'link': '/paper/Context-Encoding-for-Semantic-Segmentation-Zhang-Dana/e746c8eec81384bd37dede9700be9c8a3700f936', 'stats': ['403', 'Highly Influential', 'PDF', '']}, {'title': 'The Contextual Loss for Image Transformation with Non-Aligned Data', 'link': '/paper/The-Contextual-Loss-for-Image-Transformation-with-Mechrez-Talmi/d6e8e560100c43ea22070535b2d0e31f518ffb72', 'stats': ['116', 'Highly Influential', 'PDF']}, {'title': 'Scene Parsing through ADE20K Dataset', 'link': '/paper/Scene-Parsing-through-ADE20K-Dataset-Zhou-Zhao/2a5667702b0f1ff77dde8fb3e2e10d4e05e8de9d', 'stats': ['673', 'Highly Influential', 'PDF']}, {'title': 'Weakly Supervised Instance Segmentation Using Class Peak Response', 'link': '/paper/Weakly-Supervised-Instance-Segmentation-Using-Class-Zhou-Zhu/98a702211e52622a50691972e4aec51f996edcd5', 'stats': ['111', 'Highly Influential', 'PDF', '']}, {'title': 'Learning Deep Features for Discriminative Localization', 'link': '/paper/Learning-Deep-Features-for-Discriminative-Zhou-Khosla/31f9eb39d840821979e5df9f34a6e92dd9c879f2', 'stats': ['2,848', 'PDF', '']}, {'title': 'Deep Graphical Feature Learning for the Feature Matching Problem', 'link': '/paper/Deep-Graphical-Feature-Learning-for-the-Feature-Zhang-Lee/99a7ad6094cc288ddac895d436504441022e81d9', 'stats': ['13', 'PDF']}, {'title': 'PasteGAN: A Semi-Parametric Method to Generate Image from Scene Graph', 'link': '/paper/PasteGAN%3A-A-Semi-Parametric-Method-to-Generate-from-Li-Ma/b158b038fd34bc1cddd2711d6cd719a22b244b2e', 'stats': ['17', 'Highly Influential', 'PDF']}], 'references': []}
# -----------
# GAN and VAE from an Optimal Transport Point of View
# {'title': 'GAN and VAE from an Optimal Transport Point of View', 'corpus_id': 'Corpus ID: 88514428', 'additional_data': 'Published 2017', 'citation_count': '29', 'citations_overview': {'cit_titles': ['Highly Influencial Citations', 'Background Citations', ' Methods Citations', ' Results Citations'], 'cit_count': ['1', '14', '8', '1']}, 'topics': [], 'citations': [{'title': 'Improving GANs Using Optimal Transport', 'link': '/paper/Improving-GANs-Using-Optimal-Transport-Salimans-Zhang/69902406e7d08f8865f02185699978db499d25e7', 'stats': ['129', 'Highly Influenced', 'PDF']}, {'title': 'Asymptotic Guarantees for Learning Generative Models with the Sliced-Wasserstein Distance', 'link': '/paper/Asymptotic-Guarantees-for-Learning-Generative-with-Nadjahi-Durmus/3b8ec47d263d243a9aacf3c38149d12a13ec4b1d', 'stats': ['13', 'PDF']}, {'title': 'A Chain Graph Interpretation of Real-World Neural Networks', 'link': '/paper/A-Chain-Graph-Interpretation-of-Real-World-Neural-Shen-Cremers/b4383c0cab3d9bd66fc4b0840a40c9cc116c6be9', 'stats': []}, {'title': 'Computational Optimal Transport', 'link': '/paper/Computational-Optimal-Transport-Peyr%C3%A9-Cuturi/8e51d68250db5637cd6bc1de98a99396441399b2', 'stats': ['555', 'PDF']}, {'title': 'Design and Implementation of a plug-in for video-to-audio mapping', 'link': '/paper/Design-and-Implementation-of-a-plug-in-for-mapping-Chen/bc15ba6f0907ca6c5d5e7c7122d08ecd1f612ca5', 'stats': []}, {'title': 'A Gradual, Semi-Discrete Approach to Generative Network Training via Explicit Wasserstein Minimization', 'link': '/paper/A-Gradual%2C-Semi-Discrete-Approach-to-Generative-via-Chen-Telgarsky/6f02fa1b4dfe8f18a654cd001909c9f9ef55f01f', 'stats': ['4', 'PDF']}, {'title': 'Generative Models for Physicists', 'link': '/paper/Generative-Models-for-Physicists-Wang/99298002b471e25aec8077d44410100822405226', 'stats': ['3', 'PDF']}, {'title': 'Loosely Coupled Federated Learning Over Generative Models', 'link': '/paper/Loosely-Coupled-Federated-Learning-Over-Generative-Song-Shao/45c86cd0f5fcc401f84bad97284ffb9c9816f488', 'stats': []}, {'title': 'Sliced-Wasserstein Flows: Nonparametric Generative Modeling via Optimal Transport and Diffusions', 'link': '/paper/Sliced-Wasserstein-Flows%3A-Nonparametric-Generative-Simsekli-Liutkus/b0ab28da1f327e65c7e0c76a49faf28840ef6ffd', 'stats': ['30', 'PDF']}, {'title': "Regularized Optimal Transport and the Rot Mover's Distance", 'link': "/paper/Regularized-Optimal-Transport-and-the-Rot-Mover's-Dessein-Papadakis/9610ec402a1205cdad534ca7402d6e269e35fd07", 'stats': ['35', 'PDF']}], 'references': [{'title': 'From optimal transport to generative modeling: the VEGAN cookbook', 'link': '/paper/From-optimal-transport-to-generative-modeling%3A-the-Bousquet-Gelly/0a2605ca2c38fe45ac87b1d196a322857d8cb912', 'stats': ['92', 'Highly Influential', 'PDF']}, {'title': 'Sinkhorn-AutoDiff: Tractable Wasserstein Learning of Generative Models', 'link': '/paper/Sinkhorn-AutoDiff%3A-Tractable-Wasserstein-Learning-Genevay-Peyr%C3%A9/eafc69e017378cfebc3c5a1238410361f615533a', 'stats': ['48']}, {'title': 'Generative Adversarial Nets', 'link': '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214', 'stats': ['19,631', 'Highly Influential', 'PDF']}, {'title': 'Stochastic Optimization for Large-scale Optimal Transport', 'link': '/paper/Stochastic-Optimization-for-Large-scale-Optimal-Genevay-Cuturi/6f840ce7c8373c11f89ea1693d0cab170627d31f', 'stats': ['200', 'PDF']}, {'title': 'Auto-Encoding Variational Bayes', 'link': '/paper/Auto-Encoding-Variational-Bayes-Kingma-Welling/5f5dc5b9a2ba710937e2c413b37b053cd673df02', 'stats': ['10,212', 'Highly Influential', 'PDF']}, {'title': 'Wasserstein Training of Restricted Boltzmann Machines', 'link': '/paper/Wasserstein-Training-of-Restricted-Boltzmann-Montavon-M%C3%BCller/e5abcd3dcc1dad7354c2fa85d7142294860bd83e', 'stats': ['70', 'PDF']}, {'title': 'On minimum Kantorovich distance estimators', 'link': '/paper/On-minimum-Kantorovich-distanc ...
# -----------
# Adversarial Dual Network Learning With Randomized Image Transform for Restoring Attacked Images
# {'title': 'Adversarial Dual Network Learning With Randomized Image Transform for Restoring Attacked Images', 'corpus_id': 'Corpus ID: 211057817', 'additional_data': 'Published 2020', 'citation_count': '2', 'citations_overview': {'cit_titles': ['Highly Influencial Citations', 'Background Citations'], 'cit_count': ['1', '1']}, 'topics': ['Randomized algorithm', 'Nonlinear system', 'Deep learning', 'Black box', 'Plasma cleaning', 'Artificial neural network', 'White-box testing'], 'citations': [{'title': 'Progressive Defense Against Adversarial Attacks for Deep Learning as a Service in Internet of Things', 'link': '/paper/Progressive-Defense-Against-Adversarial-Attacks-for-Wang-Zhang/cd94282c7d2aa1f3b43ba48d3f107c54366c4f11', 'stats': []}, {'title': 'Generative adversarial networks: a survey on applications and challenges', 'link': '/paper/Generative-adversarial-networks%3A-a-survey-on-and-Kumar-Jayagopal/5ee111937e155ffd20b2ffb31d25d4c840fc1c85', 'stats': []}, {'title': 'Feature Denoising for Improving Adversarial Robustness', 'link': '/paper/Feature-Denoising-for-Improving-Adversarial-Xie-Wu/41071dbbbcbb27af3fec70de045f19c28535f5b7', 'stats': ['276', 'Highly Influential', 'PDF', '']}, {'title': 'A Direct Approach to Robust Deep Learning Using Adversarial Networks', 'link': '/paper/A-Direct-Approach-to-Robust-Deep-Learning-Using-Wang-Yu/04ee17ea05341aadc8643a21d21746cb67993a9d', 'stats': ['31', 'Highly Influential', 'PDF']}, {'title': 'Image Super-Resolution as a Defense Against Adversarial Attacks', 'link': '/paper/Image-Super-Resolution-as-a-Defense-Against-Attacks-Mustafa-Khan/578e73621da41a178a71264c9cf690adf0515574', 'stats': ['27', 'PDF', '']}, {'title': 'ComDefend: An Efficient Image Compression Model to Defend Adversarial Examples', 'link': '/paper/ComDefend%3A-An-Efficient-Image-Compression-Model-to-Jia-Wei/33e3ea69244ac597d61b9e31098b02fbfccd086d', 'stats': ['51', 'Highly Influential', 'PDF', '']}, {'title': 'Defense-GAN: Protecting Classifiers Against Adversarial Attacks Using Generative Models', 'link': '/paper/Defense-GAN%3A-Protecting-Classifiers-Against-Attacks-Samangouei-Kabkab/f7bb1636ced9036b3d0edafc7d82ad43164d41a3', 'stats': ['499', 'PDF']}, {'title': 'Adversarial Transformation Networks: Learning to Generate Adversarial Examples', 'link': '/paper/Adversarial-Transformation-Networks%3A-Learning-to-Baluja-Fischer/abf38db4775bec89c950013030d8eda56a89d32a', 'stats': ['146', 'PDF']}, {'title': 'Adversarial Defense by Restricting the Hidden Space of Deep Neural Networks', 'link': '/paper/Adversarial-Defense-by-Restricting-the-Hidden-Space-Mustafa-Khan/144a8fb6e9d573f7ffb0768846f94d7859811d44', 'stats': ['35', 'PDF', '']}, {'title': 'Mitigating adversarial effects through randomization', 'link': '/paper/Mitigating-adversarial-effects-through-Xie-Wang/9a089c56eec68df722b2a5a52727143aacdc2532', 'stats': ['381', 'PDF']}], 'references': [{'title': 'PixelDefend: Leveraging Generative Models to Understand and Defend against Adversarial Examples', 'link': '/paper/PixelDefend%3A-Leveraging-Generative-Models-to-and-Song-Kim/e83291498a3bc6b0efe8f9571e9c9ca1811707bd', 'stats': ['355', 'PDF']}, {'title': 'Improving Transferability of Adversarial Examples With Input Diversity', 'link': '/paper/Improving-Transferability-of-Adversarial-Examples-Xie-Zhang/f78a911f516625d6b7b76a9a33c1eb14613341c4', 'stats': ['128', 'PDF', '']}]}
# -----------
# Progressive Reconstruction of Visual Structure for Image Inpainting
# {'title': 'Progressive Reconstruction of Visual Structure for Image Inpainting', 'corpus_id': 'Corpus ID: 208003108', 'additional_data': 'Published 2019', 'citation_count': '10', 'citations_overview': {'cit_titles': ['Background Citations', ' Methods Citations', ' Results Citations'], 'cit_count': ['5', '2', '1']}, 'topics': ['Inpainting', 'Discriminator', 'Generalization error', 'Deconvolution', 'Computer vision', 'Convolution', 'Clone tool', 'Image restoration', 'Library (computing)', 'Experiment', 'Circuit restoration'], 'citations': [{'title': 'Recurrent Feature Reasoning for Image Inpainting', 'link': '/paper/Recurrent-Feature-Reasoning-for-Image-Inpainting-Li-Wang/20334266b089240d6d723efdc17511d4929a434a', 'stats': ['4', 'PDF']}, {'title': 'Image Inpainting Guided by Coherence Priors of Semantics and Textures', 'link': '/paper/Image-Inpainting-Guided-by-Coherence-Priors-of-and-Liao-Xiao/26a8e0c99574ade64b9c02a69cb0df1c8c840c50', 'stats': []}, {'title': 'EraseNet: End-to-End Text Removal in the Wild', 'link': '/paper/EraseNet%3A-End-to-End-Text-Removal-in-the-Wild-Liu-Liu/188feb685237ffbfd50aa2419e5ae30381cc967d', 'stats': []}, {'title': 'Multistage attention network for image inpainting', 'link': '/paper/Multistage-attention-network-for-image-inpainting-Wang-Ma/3fb37054b15fe1ebf276dc6d52ecf4fe82a8ecb2', 'stats': ['5']}, {'title': 'Guidance and Evaluation: Semantic-Aware Image Inpainting for Mixed Scenes', 'link': '/paper/Guidance-and-Evaluation%3A-Semantic-Aware-Image-for-Liao-Xiao/a0f3c02896a1e23baf44db8cda1ee06a4cea9bfd', 'stats': ['2', 'PDF']}, {'title': 'Edge Guided GANs with Semantic Preserving for Semantic Image Synthesis', 'link': '/paper/Edge-Guided-GANs-with-Semantic-Preserving-for-Image-Tang-Qi/453d41957a9a0ee807790be4f673da147128d468', 'stats': ['4', 'PDF']}, {'title': 'R-MNet: A Perceptual Adversarial Network for Image Inpainting', 'link': '/paper/R-MNet%3A-A-Perceptual-Adversarial-Network-for-Image-Jam-Kendrick/42c14218ab4d8eb435e31441e3738cec06362ce3', 'stats': ['1', 'PDF']}, {'title': 'PuppeteerGAN: Arbitrary Portrait Animation With Semantic-Aware Appearance Transformation', 'link': '/paper/PuppeteerGAN%3A-Arbitrary-Portrait-Animation-With-Chen-Wang/0d5a05bd182e27df36a115a10ebba766962653fc', 'stats': ['4', 'PDF']}, {'title': 'Fast Generation of High Fidelity RGB-D Images by Deep-Learning with Adaptive Convolution', 'link': '/paper/Fast-Generation-of-High-Fidelity-RGB-D-Images-by-Xian-Zhang/36e9a73064d75a2da28e119b00da365ebe211062', 'stats': []}, {'title': 'Image Fine-grained Inpainting', 'link': '/paper/Image-Fine-grained-Inpainting-Hui-Li/065dcfb0b9d60d0af330b85eaa11db6a1a1e8ff4', 'stats': ['2', 'PDF']}], 'references': [{'title': 'EdgeConnect: Generative Image Inpainting with Adversarial Edge Learning', 'link': '/paper/EdgeConnect%3A-Generative-Image-Inpainting-with-Edge-Nazeri-Ng/f6284d750cf12669ca3bc12a1b485545af776239', 'stats': ['176', 'PDF']}, {'title': 'Generative Image Inpainting with Contextual Attention', 'link': '/paper/Generative-Image-Inpainting-with-Contextual-Yu-Lin/6b0bbf3e7df725cc3b781d2648e41782cb3d8539', 'stats': ['692', 'Highly Influential', 'PDF', '']}, {'title': 'High-Resolution Image Synthesis and Semantic Manipulation with Conditional GANs', 'link': '/paper/High-Resolution-Image-Synthesis-and-Semantic-with-Wang-Liu/f0a0c0f0d6a7ff53abea40a8c0c678ed570bf851', 'stats': ['1,253', 'PDF', '']}, {'title': 'High-Resolution Image Inpainting Using Multi-scale Neural Patch Synthesis', 'link': '/paper/High-Resolution-Image-Inpainting-Using-Multi-scale-Yang-Lu/3b9bfdeeb9ac6ada5a5833b1f179cb97f3e6804b', 'stats': ['419', 'PDF', '']}, {'title': 'Shift-Net: Image Inpainting via Deep Feature Rearrangement', 'link': '/paper/Shift-Net%3A-Image-Inpainting-via-Deep-Feature-Yan-Li/904decf94f5495d1488e2bf22e3ed4df500ce4d5', 'stats': ['112', 'PDF']}, {'title': 'Adversarial Scene Editing: Automatic Object Removal from Weak Supervision', 'link': '/paper/Adversarial-Scene-Editing%3A-Automatic-Object-Removal-Sh ...
# -----------
# Improving k-Means Clustering Performance with Disentangled Internal Representations
# {'title': 'Improving k-Means Clustering Performance with Disentangled Internal Representations', 'corpus_id': 'Corpus ID: 219531498', 'additional_data': 'Published 2020', 'citation_count': '', 'citations_overview': {}, 'topics': ['Cluster analysis', 'MNIST database', 'Autoencoder', 'Deep learning', 'Feature learning', 'Quantum entanglement', 'K-means clustering', 'Artificial neural network', 'Data point', 'Baseline (configuration management)', 'Algorithm', 'Simulated annealing', 'Machine learning'], 'citations': [{'title': 'N2D: (Not Too) Deep Clustering via Clustering the Local Manifold of an Autoencoded Embedding', 'link': '/paper/N2D%3A-(Not-Too)-Deep-Clustering-via-Clustering-the-McConville-Santos-Rodr%C3%ADguez/590eb330c6a9fd8ef1317ec0b57dcff9e0b10e64', 'stats': ['20', 'Highly Influential', 'PDF']}, {'title': 'ClusterGAN : Latent Space Clustering in Generative Adversarial Networks', 'link': '/paper/ClusterGAN-%3A-Latent-Space-Clustering-in-Generative-Mukherjee-Asnani/0943ba71d5a4d839a4d2d88a8aee72025fb77982', 'stats': ['75', 'Highly Influential', 'PDF']}, {'title': 'Variational Deep Embedding: An Unsupervised and Generative Approach to Clustering', 'link': '/paper/Variational-Deep-Embedding%3A-An-Unsupervised-and-to-Jiang-Zheng/f708482e99ed40a2fb9e363577479e1fd15afc9f', 'stats': ['231', 'Highly Influential', 'PDF']}, {'title': 'Unsupervised Deep Embedding for Clustering Analysis', 'link': '/paper/Unsupervised-Deep-Embedding-for-Clustering-Analysis-Xie-Girshick/f44ff4fc0ed0142cb18472a5ba421bb538aa837e', 'stats': ['815', 'Highly Influential', 'PDF']}, {'title': 'Analyzing and Improving Representations with the Soft Nearest Neighbor Loss', 'link': '/paper/Analyzing-and-Improving-Representations-with-the-Frosst-Papernot/1bf49ef0b33bf8fcc3ebdd16326db419f3af65d8', 'stats': ['31', 'Highly Influential', 'PDF']}, {'title': 'Delving Deep into Rectifiers: Surpassing Human-Level Performance on ImageNet Classification', 'link': '/paper/Delving-Deep-into-Rectifiers%3A-Surpassing-on-He-Zhang/d6f2f611da110b5b5061731be3fc4c7f45d8ee23', 'stats': ['8,648', 'PDF', '']}, {'title': 'Deep Residual Learning for Image Recognition', 'link': '/paper/Deep-Residual-Learning-for-Image-Recognition-He-Zhang/2c03df8b48bf3fa39054345bafabfeff15bfd11d', 'stats': ['55,946', 'PDF', '']}, {'title': 'Adding Gradient Noise Improves Learning for Very Deep Networks', 'link': '/paper/Adding-Gradient-Noise-Improves-Learning-for-Very-Neelakantan-Vilnis/6f5a0fbb1473e95d0a14ef2081985d16bc063bfb', 'stats': ['292', 'PDF']}, {'title': 'Learning Multiple Layers of Features from Tiny Images', 'link': '/paper/Learning-Multiple-Layers-of-Features-from-Tiny-Krizhevsky/5d90f06bb70a0a3dced62413346235c02b1aa086', 'stats': ['9,740', 'PDF']}, {'title': 'Visualizing Data using t-SNE', 'link': '/paper/Visualizing-Data-using-t-SNE-Maaten-Hinton/1c46943103bd7b7a2c7be86859995a4144d1938b', 'stats': ['15,084', 'PDF']}], 'references': []}
# -----------
# Distributionally Robust Games: Wasserstein Metric
# {'title': 'Distributionally Robust Games: Wasserstein Metric', 'corpus_id': 'Corpus ID: 52987236', 'additional_data': 'Published 2018', 'citation_count': '2', 'citations_overview': {'cit_titles': ['Background Citations', ' Methods Citations'], 'cit_count': ['1', '2']}, 'topics': ['Game theory', 'Kullback–Leibler divergence', 'Algorithm', 'Minimax', 'Speech synthesis', 'Robust optimization', 'Feature vector', 'Generative model', 'Performance Evaluation', 'Computation', 'Loss function', 'Instability', 'Best, worst and average case', 'Mathematical optimization', 'Discrepancy function', 'Encoder', 'Artificial neural network', 'Digital raster graphic', 'Deep learning', 'Neural Networks'], 'citations': [{'title': 'Research Progress of Convolutional Neural Network and its Application in Object Detection', 'link': '/paper/Research-Progress-of-Convolutional-Neural-Network-Zhang-Zeng/b8e79f7d1c3199cf6321c0079f97bda766db6504', 'stats': []}, {'title': 'Bregman learning for generative adversarial networks', 'link': '/paper/Bregman-learning-for-generative-adversarial-Gao-Tembine/a8760dc83e8cb88f241cc206855fbbad680889a0', 'stats': ['1']}, {'title': 'Learning Generative Models with Sinkhorn Divergences', 'link': '/paper/Learning-Generative-Models-with-Sinkhorn-Genevay-Peyr%C3%A9/a1bc7d90564c342beb75cedf36fd921de89d94ad', 'stats': ['209', 'PDF']}, {'title': 'Distributionally Robust Games: f-Divergence and Learning', 'link': '/paper/Distributionally-Robust-Games%3A-f-Divergence-and-Bauso-Gao/bd496a44fb4b8d998d46e700a57ef08dc4d48074', 'stats': ['6', 'PDF']}, {'title': 'Generative Adversarial Nets', 'link': '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214', 'stats': ['19,631', 'Highly Influential', 'PDF']}, {'title': 'Generative Moment Matching Networks', 'link': '/paper/Generative-Moment-Matching-Networks-Li-Swersky/c8b509be29721ee6b12c880b4d97ed6b60bad217', 'stats': ['501', 'PDF']}, {'title': 'A Fast Learning Algorithm for Deep Belief Nets', 'link': '/paper/A-Fast-Learning-Algorithm-for-Deep-Belief-Nets-Hinton-Osindero/8978cf7574ceb35f4c3096be768c7547b28a35d0', 'stats': ['11,383', 'PDF']}, {'title': 'On the Quantitative Analysis of Decoder-Based Generative Models', 'link': '/paper/On-the-Quantitative-Analysis-of-Decoder-Based-Wu-Burda/858dc7408c27702ec42778599fc8d11f73ef3f76', 'stats': ['170', 'PDF']}, {'title': 'Auto-Encoding Variational Bayes', 'link': '/paper/Auto-Encoding-Variational-Bayes-Kingma-Welling/5f5dc5b9a2ba710937e2c413b37b053cd673df02', 'stats': ['10,212', 'Highly Influential', 'PDF']}, {'title': 'A note on the evaluation of generative models', 'link': '/paper/A-note-on-the-evaluation-of-generative-models-Theis-Oord/39e0c341351f8f4a39ac890b96217c7f4bde5369', 'stats': ['645', 'PDF']}], 'references': [{'title': 'Optimization Methods for Large-Scale Machine Learning', 'link': '/paper/Optimization-Methods-for-Large-Scale-Machine-Bottou-Curtis/d21703674ae562bae4a849a75847cdd9ead417df', 'stats': ['1,144', 'PDF']}, {'title': 'Improved Techniques for Training GANs', 'link': '/paper/Improved-Techniques-for-Training-GANs-Salimans-Goodfellow/571b0750085ae3d939525e62af510ee2cee9d5ea', 'stats': ['3,866', 'PDF']}]}
# -----------
# GenEval: A Benchmark Suite for Evaluating Generative Models
# {'title': 'GenEval: A Benchmark Suite for Evaluating Generative Models', 'corpus_id': 'Corpus ID: 53351804', 'additional_data': 'Published 2018', 'citation_count': '', 'citations_overview': {}, 'topics': ['Benchmark (computing)', 'Generative model', 'Robotics', 'Visual inspection', 'Image processing', 'Modality (human–computer interaction)', 'Causal filter', 'Numerous'], 'citations': [{'title': 'A note on the evaluation of generative models', 'link': '/paper/A-note-on-the-evaluation-of-generative-models-Theis-Oord/39e0c341351f8f4a39ac890b96217c7f4bde5369', 'stats': ['645', 'PDF']}, {'title': 'Are GANs Created Equal? A Large-Scale Study', 'link': '/paper/Are-GANs-Created-Equal-A-Large-Scale-Study-Lucic-Kurach/c88e8d85fd5160b0793598bda037f977366acf7a', 'stats': ['467', 'Highly Influential', 'PDF']}, {'title': 'Improved Techniques for Training GANs', 'link': '/paper/Improved-Techniques-for-Training-GANs-Salimans-Goodfellow/571b0750085ae3d939525e62af510ee2cee9d5ea', 'stats': ['3,866', 'PDF']}, {'title': 'Generative Adversarial Nets', 'link': '/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214', 'stats': ['19,631', 'Highly Influential', 'PDF']}, {'title': 'The GAN Landscape: Losses, Architectures, Regularization, and Normalization', 'link': '/paper/The-GAN-Landscape%3A-Losses%2C-Architectures%2C-and-Kurach-Lucic/5b713f00eb7ebe21064321e73be8f32455a76799', 'stats': ['104', 'PDF']}, {'title': 'Stabilizing Training of Generative Adversarial Networks through Regularization', 'link': '/paper/Stabilizing-Training-of-Generative-Adversarial-Roth-Lucchi/698d3b667a7f3073eed8368d9daf84f990c24a65', 'stats': ['238', 'Highly Influential', 'PDF']}, {'title': 'Progressive Growing of GANs for Improved Quality, Stability, and Variation', 'link': '/paper/Progressive-Growing-of-GANs-for-Improved-Quality%2C-Karras-Aila/744fe47157477235032f7bb3777800f9f2f45e52', 'stats': ['2,327', 'Highly Influential', 'PDF']}, {'title': 'Improved Training of Wasserstein GANs', 'link': '/paper/Improved-Training-of-Wasserstein-GANs-Gulrajani-Ahmed/edf73ab12595c6709f646f542a0d2b33eb20a3f4', 'stats': ['3,674', 'Highly Influential', 'PDF']}, {'title': 'Auto-Encoding Variational Bayes', 'link': '/paper/Auto-Encoding-Variational-Bayes-Kingma-Welling/5f5dc5b9a2ba710937e2c413b37b053cd673df02', 'stats': ['10,212', 'Highly Influential', 'PDF']}, {'title': 'Do GANs actually learn the distribution? An empirical study', 'link': '/paper/Do-GANs-actually-learn-the-distribution-An-study-Arora-Zhang/f89e5a8800b318fa03289b5cc67df54b956875b4', 'stats': ['129', 'PDF']}], 'references': []}
# -----------
# Towards Structured Prediction in Bioinformatics with Deep Learning
# {'title': 'Towards Structured Prediction in Bioinformatics with Deep Learning', 'corpus_id': 'Corpus ID: 221319641', 'additional_data': 'Published 2020', 'citation_count': '', 'citations_overview': {}, 'topics': [], 'citations': [{'title': 'Deep learning in bioinformatics: introduction, application, and perspective in big data era', 'link': '/paper/Deep-learning-in-bioinformatics%3A-introduction%2C-and-Li-Huang/6966d2b49fa885897e0b2e18ce144831c55f3e5f', 'stats': ['51', 'Highly Influential', 'PDF']}, {'title': 'Modern Deep Learning in Bioinformatics.', 'link': '/paper/Modern-Deep-Learning-in-Bioinformatics.-Li-Tian/04b71445fca3e98d4f572284a15ccb7d6c7cb917', 'stats': ['4', 'PDF']}, {'title': 'Learning and Inference for Structured Prediction: A Unifying Perspective', 'link': '/paper/Learning-and-Inference-for-Structured-Prediction%3A-A-Deshwal-Doppa/ff0180c29a2fa5aa6ee76fc5eb35891b99d01929', 'stats': ['2', 'PDF']}, {'title': 'Structured Prediction Energy Networks', 'link': '/paper/Structured-Prediction-Energy-Networks-Belanger-McCallum/bc82b4f9f202062857958f0336fc28327a75563b', 'stats': ['136', 'PDF']}, {'title': 'DEEPre: sequence-based enzyme EC number prediction by deep learning', 'link': '/paper/DEEPre%3A-sequence-based-enzyme-EC-number-prediction-Li-Wang/c2657207664566d8c5c5a7071a1bd85d9c62d498', 'stats': ['86', 'Highly Influential', 'PDF']}, {'title': 'mlDEEPre: Multi-Functional Enzyme Function Prediction With Hierarchical Multi-Label Deep Learning', 'link': '/paper/mlDEEPre%3A-Multi-Functional-Enzyme-Function-With-Zou-Tian/6633c836ce97ae7d250fc33b6e23dfd60ad12152', 'stats': ['23', 'Highly Influential', 'PDF']}, {'title': 'Protein Secondary Structure Prediction Using Deep Convolutional Neural Fields', 'link': '/paper/Protein-Secondary-Structure-Prediction-Using-Deep-Wang-Peng/c8fd51f56a3cb6920e17656b67ca79051d2496c0', 'stats': ['291', 'Highly Influential', 'PDF']}, {'title': 'Learning Approximate Inference Networks for Structured Prediction', 'link': '/paper/Learning-Approximate-Inference-Networks-for-Tu-Gimpel/b34e44d48c35750456d50d225c026536596b83fa', 'stats': ['32', 'PDF']}, {'title': 'Promoter analysis and prediction in the human genome using sequence-based deep learning models', 'link': '/paper/Promoter-analysis-and-prediction-in-the-human-using-Umarov-Kuwahara/89d223476d6ab92173423f54f595003e804fd941', 'stats': ['23', 'PDF']}, {'title': 'AUC-Maximized Deep Convolutional Neural Fields for Protein Sequence Labeling', 'link': '/paper/AUC-Maximized-Deep-Convolutional-Neural-Fields-for-Wang-Sun/a1aa68dd07cda8101ef4e4c95719db0cbaa107c4', 'stats': ['17', '']}], 'references': []}
# -----------

# %% [markdown]
# ## Word cloud using topics list from  parsed data

# %%
top_list = [entry['topics'] for entry in dta]
topics = ravel(top_list)
generate_wcloud(topics,max_words=50)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f964e6b8910>

# %% [markdown]
# ## Simple endpoint on scrapper function

# %%
from flask import Flask
from flask_restful import Resource, Api, reqparse
import pandas as pd
import ast
app = Flask(__name__)
api = Api(app)


class Parser(Resource):
    def get(self):
        parser = reqparse.RequestParser()  # initialize
        
        parser.add_argument('paper_id', required=True)  # add args

        
        args = parser.parse_args()
        paper_where =args['paper_id']
        soup = get_shemantic_paper_html(paper_where)
        data = extract_data(soup)
        #print(paper_where)
        
         
        return data, 200  # return data and 200 OK code
    

    
api.add_resource(Parser, '/parse') 


if __name__ == '__main__':
    app.run()  # run our Flask app
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
## copy past this url in your browser after running the server 
url = 'http://127.0.0.1:5000/parse?paper_id=/paper/Generative-Adversarial-Nets-Goodfellow-Pouget-Abadie/54e325aee6b2d476bbbb88615ac15e251c6e8214'
